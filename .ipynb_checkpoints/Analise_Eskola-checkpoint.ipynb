# %%
import pandas as pd

# %%
nome_dataframeA1 = pd.read_csv('dados.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])
nome_dataframeA2 = pd.read_csv('dados3.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])
nome_dataframeA3 = pd.read_csv('dados2.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])

# %%
A1 = line(zip(nome_dataframeA1['Coluna1'], nome_dataframeA1['Coluna2']), thickness=2,legend_label="EPS21",
          color="#1f77b4")  # Azul
A2 = line(zip(nome_dataframeA2['Coluna1'], nome_dataframeA2['Coluna2']), thickness=2,legend_label="nCTEQ15",
          color="#000000", linestyle="-")  # Azul
A3 = line(zip(nome_dataframeA3['Coluna1'], nome_dataframeA3['Coluna2']), thickness=2,legend_label="nNNPDF2.0",
          color="#1f55b4", linestyle="-.")  # Azul
b=A1

# %%
b.show(figsize=(8,4), frame=true, axes=false, xmin = -6 , xmax =6, ymax = 7e-4)
# Out:
# Graphics object consisting of 1 graphics primitive
