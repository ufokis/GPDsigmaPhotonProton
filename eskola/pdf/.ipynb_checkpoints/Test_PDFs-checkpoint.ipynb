# %%
import pandas as pd
import subprocess

compile =  ["gfortran", "Test_PDFs.f90",  "-o",  "Test_PDFs.out",  "-L", "/home/eliton/lhapdf2/lib",  "-lLHAPDF"]
# compile the command
try:
    subprocess.run(compile, check=True)
except subprocess.CalledProcessError as e:
    print(f"Error executing command: {e}")

# %%
# Define variables
name = "nCTEQ15_208_82"
Q = "2.37"

# Command and arguments
command = ["./Test_PDFs.out", "-Q", Q, "-name", name]

# Execute the command
try:
    subprocess.run(command, check=True)
except subprocess.CalledProcessError as e:
    print(f"Error executing command: {e}")
# Out:
# LHAPDF 6.5.2 loading /home/eliton/lhapdf2/share/LHAPDF/nCTEQ15_208_82/nCTEQ15_208_82_0000.dat
# nCTEQ15_208_82 PDF set, member #0, version 1; LHAPDF ID = 101100
#  xmin=   5.0000000000000004E-006  xmax=   1.0000000000000000       Q2min=   0.0000000000000000       Q2max=   2.7077817121327692E-315
#  xmin=   5.0000000000000004E-006  xmax=   1.0000000000000000       Q2min=   1.6900000000000002       Q2max=   100000000.00000000
# Thanks for using LHAPDF 6.5.2. Please make sure to cite the paper:
#   Eur.Phys.J. C75 (2015) 3, 132  (http://arxiv.org/abs/1412.7420)

# %%
nome_dataframeA1 = pd.read_csv('pdf1_'+name+'.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])

nome_dataframeA2 = pd.read_csv('pdf2_'+name+'.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])

# %%
A1 = line(zip(nome_dataframeA1['Coluna1'], nome_dataframeA1['Coluna2']), thickness=1,legend_label="$F_g$"+name,
          color="#1f77b4")  # Azul
A2 = line(zip(nome_dataframeA2['Coluna1'], nome_dataframeA2['Coluna2']), thickness=1,legend_label="$F_{qs}$"+name,
          color="#000000" )  # Azul


Grafico1 = A1 + A2

# %%
# Define variables
name = "EPPS16nlo_CT14nlo_Pb208"
Q = "2.37"

# Command and arguments
command = ["./Test_PDFs.out", "-Q", Q, "-name", name]

# Execute the command
try:
    subprocess.run(command, check=True)
except subprocess.CalledProcessError as e:
    print(f"Error executing command: {e}")
# Out:
# LHAPDF 6.5.2 loading /home/eliton/lhapdf2/share/LHAPDF/EPPS16nlo_CT14nlo_Pb208/EPPS16nlo_CT14nlo_Pb208_0000.dat
# EPPS16nlo_CT14nlo_Pb208 PDF set, member #0, version 1; LHAPDF ID = 901300
#  xmin=   9.9999999999999995E-008  xmax=   1.0000000000000000       Q2min=   0.0000000000000000       Q2max=   5.7208276937605477E-315
#  xmin=   9.9999999999999995E-008  xmax=   1.0000000000000000       Q2min=   1.6900000000000002       Q2max=   100000000.00000000
# Thanks for using LHAPDF 6.5.2. Please make sure to cite the paper:
#   Eur.Phys.J. C75 (2015) 3, 132  (http://arxiv.org/abs/1412.7420)

# %%
nome_dataframeA1 = pd.read_csv('pdf1_'+name+'.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])

nome_dataframeA2 = pd.read_csv('pdf2_'+name+'.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])

# %%
B1 = line(zip(nome_dataframeA1['Coluna1'], nome_dataframeA1['Coluna2']), thickness=1,legend_label="$F_g$"+name,
          color="#1f77b4")  # Azul
B2 = line(zip(nome_dataframeA2['Coluna1'], nome_dataframeA2['Coluna2']), thickness=1,legend_label="$F_{qs}$"+name,
          color="#000000" )  # Azul


Grafico2 = B1 + B2

# %%
# Define variables
name = "nNNPDF20_nlo_as_0118_Pb208"
Q = "2.37"

# Command and arguments
command = ["./Test_PDFs.out", "-Q", Q, "-name", name]

# Execute the command
try:
    subprocess.run(command, check=True)
except subprocess.CalledProcessError as e:
    print(f"Error executing command: {e}")
# Out:
# LHAPDF 6.5.2 loading /home/eliton/lhapdf2/share/LHAPDF/nNNPDF20_nlo_as_0118_Pb208/nNNPDF20_nlo_as_0118_Pb208_0000.dat
# nNNPDF20_nlo_as_0118_Pb208 PDF set, member #0, version 1; LHAPDF ID = 30014500
#  xmin=   1.0000000000000001E-009  xmax=   1.0000000000000000       Q2min=   6.7457415300953295E-310  Q2max=   4.9406564584124654E-324
#  xmin=   1.0000000000000001E-009  xmax=   1.0000000000000000       Q2min=   1.0000000000000000       Q2max=   10000000000.000000
# Thanks for using LHAPDF 6.5.2. Please make sure to cite the paper:
#   Eur.Phys.J. C75 (2015) 3, 132  (http://arxiv.org/abs/1412.7420)

# %%
nome_dataframeA1 = pd.read_csv('pdf1_'+name+'.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])

nome_dataframeA2 = pd.read_csv('pdf2_'+name+'.dat', delim_whitespace=True,
                               header=None, names=["Coluna1", "Coluna2"])

# %%
C1 = line(zip(nome_dataframeA1['Coluna1'], nome_dataframeA1['Coluna2']), thickness=1,legend_label="$F_g$"+name,
          color="#1f77b4")  # Azul
C2 = line(zip(nome_dataframeA2['Coluna1'], nome_dataframeA2['Coluna2']), thickness=1,legend_label="$F_{qs}$"+name,
          color="#000000" )  # Azul


Grafico3 = C1 + C2

# %%
Grafico =  Grafico1 + Grafico2 + Grafico3

# %%
Grafico.show(figsize=(7,4), frame=true, axes=false, ymax = 1e7, ymin = 1, scale='loglog')
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
from sage.plot.plot import plot
from matplotlib import ticker

# Defina a função
f = 1 - 2*x^2

# Crie o gráfico
A = plot(f, x, 0.707106, 0.707107, frame=True, axes=false)

# Defina o formato do marcador
TT = ticker.FormatStrFormatter('%.5f')


# Adicione um segundo eixo x no topo
A.top_edge = false

A.show(tick_formatter=[TT, None])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
g = Graphics()
g += region_plot([x / 2 + 7 <= y, y <= (x - 7) * 2], (10, 57), (10, 100), incol="#ffeeee")
g += plot(x, (x, 14, 57), color="red", linestyle="--")
g.show(axes_labels=["your age (years)", "partner's age (years)"], title="Dateable age range")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Create the main plot
p = plot(sin(x), x, 0, 10, axes_labels=['X', 'Y'], color='blue')

# Add axes on all sides
p.show(frame=True)



# Add labels for each axis
p.axes_labels(['Left', 'Bottom', 'Right', 'Top'])

# Show the plot
p.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 2
#       1 # Create the main plot
# ----> 2 p = plot(sin(x), x, Integer(0), Integer(10), axes_labels=['X', 'Y'], color='blue')
#       4 # Add axes on all sides
#       5 p.show(frame=True)
#
# File /usr/lib/python3.11/site-packages/sage/misc/decorators.py:497, in options.__call__.<locals>.wrapper(*args, **kwds)
#     495     options['__original_opts'] = kwds
#     496 options.update(kwds)
# --> 497 return func(*args, **options)
#
# File /usr/lib/python3.11/site-packages/sage/plot/plot.py:2063, in plot(funcs, *args, **kwds)
#    2061     xmax = args[2]
#    2062     args = args[3:]
# -> 2063     G = _plot(funcs, (var, xmin, xmax), *args, **kwds)
#    2064 elif ('xmin' in kwds) or ('xmax' in kwds):
#    2065     xmin = kwds.pop('xmin', -1)
#
# ...
